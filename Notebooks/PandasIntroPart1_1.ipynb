# %% [markdown]
# # Pandas Intro and Basic File Management
# [Basic OS Management](#BasicOSManagement)
# [Read Data](#ReadData)

# %% [markdown]
# <a id="BasicOSManagement"></a>
# ## 1. Basic OS Management in Notebook
# ### Typically ALL the imported packages should be together in a single cell at the top of your notebook

# %%
import os

# %% [markdown]
# ## What is the current working directory (folder) of this notebook and what’s actually in it (a list of files and folders)?
# ### This will show where you are currently working within your computer's folders. Make sure you know where this folder is. look at the way the path is written in the output that is the form that you need to use. It is different for Windows and Macs

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mdb025\\Documents\\Courses\\Analytics Course Materials\\Machine Learning\\ANOP 330\\ANOP330_F2021\\ANOP330F21_Notebooks'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Assignment_HealthInsuranceCost_EDA_Reg_Soln.pdf',
#  'CO2_DataViz.ipynb',
#  'Data',
#  'F_MNIST_Data.png',
#  'HealthInsuranceCost_EDA_Reg_Soln.ipynb',
#  'HW1_PandasIntro_soln.ipynb',
#  'HW1_PandasIntro_soln_PDF.pdf',
#  'HW1_PandasIntro_std.ipynb',
#  'InClassNotes_9_9.ipynb',
#  'NBA_Salary_Regressoin_SOLN_v2.pdf',
#  'NeuralNetworks_MLP_FashionExp_1.ipynb',
#  'Overview Pandas and Partition v1.ipynb',
#  'Overview Pandas and Partition v2.ipynb',
#  'PandasIntro_Inprogress_Notebook_8_27.ipynb',
#  'plot_mnist_filters.ipynb',
#  'ProfBaileyNotesPandasIntro.ipynb',
#  'Python_regression_results.ipynb',
#  'RegressionPractice',
#  'Submit.csv',
#  'TitanicLogitClassifierAssignment_Soln_PDF.pdf',
#  'TitanicLogReg_soln-Copy1.ipynb',
#  'TitanicLogReg_soln.ipynb',
#  'TitanicRulePredAssignment_soln.ipynb',
#  'TitanicRulePredAssignment_Soln_PDF.pdf',
#  'Untitled.ipynb',
#  'VehiclesEDA_Assignment_Soln.ipynb',
#  'VehiclesEDA_Assignment_Soln_PDF.pdf']

# %% [markdown]
# ## I want to move to a new folder (change directory)! Provide a string with the path.
# (tip: If you copy and paste from office or the web, the quote characters may be copied incorrectly (“ vs. ") and that wlll throw an error. Just retype the quotes to fix.)

# %%
os.chdir("C:\\Users\\mdb025\\Desktop")
#can view what's in the folder if wanted
#os.listdir()

# %% [markdown]
# ## You could also create a path object, check it exists, and move there
# ### Need to import the function Path from the pathlib package (if you don't want to import an entire package and ALL it's functions, you can just import the ones you need using `from [package name] import [function(s) names]`.

# %%
from pathlib import Path
p = Path('C:\\Users\\mdb025\\Documents\\Courses\\Analytics Course Materials\\Machine Learning')
p.exists()
# Out:
# True

# %%
#move working directory to this path
os.chdir(p)

# %% [markdown]
# <a id="ReadData"></a>
# ## 1. Read in Data
# ### Now move to to your original directory (folder) where your Data folder exists and holds the data file `movie.csv`

# %%
os.chdir('C:\\Users\\mdb025\\Documents\\Courses\\Analytics Course Materials\\Machine Learning\\ANOP 330\\ANOP330_F2021\\ANOP330F21_Notebooks')

# %% [markdown]
# ### If the file is in the working directory, then you can just open it by name, otherwise, you may need to add part of the (or the full) path to the file. It's not a bad idea to check the file exists before you try to open it.

# %%
os.path.isfile("Data\\movie.csv")
# Out:
# True

# %% [markdown]
# ### We are going to import using common aliases for our bread and butter packages `pandas` and `numpy`

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read the data inta a pandas DataFrame (from a downloaded file or even a file from the web). Common convention is to add `df_` as a prefix or `_df` as a suffix to the name for clarity. You'll see both conventions when you look at sample code. Different data file types require different read functions (or options). `read_csv`, `read_excel`, and `read_json` or the most common. There are alternatives for database files also. We'll mostly stick with comma-separated values (CSV) files.
# ### Whenever we see a new function, do not assume that all you see is all there is, there are MANY optional inputs that you should be exploring! Click and review!
# [pandas.read_csv](https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.read_csv.html)
#
# [pandas.read_excel](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)
#
# [pandas.read_json](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html)

# %%
df_movies = pd.read_csv("Data\\movie.csv")

#could even read the file from a website if you can find a direct link. 
#This also saves you from having to download and store on your computer (good)
#but you need to have internet access each time your run (bad)
#df_movies = pd.read_csv("https://raw.githubusercontent.com/MattDBailey/ANOP330/main/Data/movie.csv")

# %% [markdown]
# ### What's in this data?

# %%
df_movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ### Can we get a cleaner view of this data? Look at the top few rows `.head()` or the last few rows `.tail()` or a random sample `.sample()`

# %%
df_movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df_movies.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
df_movies.sample(5)
# Out:
#       color       director_name  num_critic_for_reviews  duration  \
# 1139  Color     Louis Leterrier                   177.0     103.0
# 4430  Color       Mona Fastvold                    16.0      91.0
# 1366  Color     Nick Cassavetes                   129.0     116.0
# 580   Color        Paul Tibbitt                   147.0      92.0
# 4542  Color  Mariette Monpierre                     2.0      78.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 1139                    255.0                  5000.0             Jet Li
# 4430                      2.0                     9.0       Brady Corbet
# 1366                    415.0                   644.0      Laura Harring
# 580                       5.0                   726.0         Billy West
# 4542                      0.0                     0.0  Christophe Cherki
#
#       actor_1_facebook_likes        gross  \
# 1139                 11000.0   24520892.0
# ...

# %% [markdown]
# ### What are some ATTRIBUTES of the DataFrame?

# %%
df_movies.shape
# Out:
# (4916, 28)

# %%
#show all the columns and store them
cols = df_movies.columns
cols
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#show the index (row names)
ind = df_movies.index
ind
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %% [markdown]
# ### See slides for the data dictionary. You should ALWAYS provide your reader a data dictionary (included created fields). The correctness of your analysis is COMPLETELY dependent on the what each data field (and row) represents! It's the data is the product for building, so you better understand your product.

# %% [markdown]
# ## What are the types of data?
# ### pandas tries to guess what the data types are, so check that it guessed correctly (dates as datetime, integers as integers, etc.). Watch out for numerical fields that are actually categorical (or objects). Such as 0=Monday, 1=Tuesday, etc.. See slides for types.

# %%
df_movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
df_movies['content_rating'].value_counts()
# Out:
# R            2067
# PG-13        1411
# PG            686
# Not Rated     115
# G             112
# Unrated        59
# Approved       54
# TV-14          30
# TV-MA          18
# TV-PG          13
# X              12
# TV-G           10
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-Y7           1
# TV-Y            1
# Name: content_rating, dtype: int64

# %%
df_movies['content_rating'].astype('category').cat.categories
# Out:
# Index(['Approved', 'G', 'GP', 'M', 'NC-17', 'Not Rated', 'PG', 'PG-13',
#        'Passed', 'R', 'TV-14', 'TV-G', 'TV-MA', 'TV-PG', 'TV-Y', 'TV-Y7',
#        'Unrated', 'X'],
#       dtype='object')

# %% [markdown]
# ## Let's get some information about the fields (columns)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %% [markdown]
# ## Here is a function that I found to decrease the memory of your data set by picking a smaller data type (e.g., 8 bit float from 64 bit float)
# ## It isn't much of an issue for our in-class data, but handy for larger data sets.

# %%
# Function to decrease data usage in notebook (from Baek Kyun Shin)
def downcast(df, verbose=True):
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        dtype_name = df[col].dtype.name
        if dtype_name == 'object':
            pass
        elif dtype_name == 'bool':
            df[col] = df[col].astype('int8')
        elif dtype_name.startswith('int') or (df[col].round() == df[col]).all():
            df[col] = pd.to_numeric(df[col], downcast='integer')
        else:
            df[col] = pd.to_numeric(df[col], downcast='float')
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print('{:.1f}% Compressed'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
df_movies = downcast(df_movies)
# Out:
# 28.6% Compressed

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float32
#  3   duration                   4901 non-null   float32
#  4   director_facebook_likes    4814 non-null   float32
#  5   actor_3_facebook_likes     4893 non-null   float32
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float32
#  8   gross                      4054 non-null   float32
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int32
# ...

# %% [markdown]
# ##  Reduced from 1.1 MB (1100 KB) to 0.768 MB (768 KB) a 28.6% reduction in memory! Mostly from moving from float64 and int64 to float32 and int32.

# %%
director = df_movies.director_name

# %%
director.head()
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
director.dtypes
# Out:
# dtype('O')

# %%
director.size
# Out:
# 4916

# %%
fb_A1likes = df_movies.actor_1_facebook_likes

# %%
fb_A1likes.count()
# Out:
# 4909

# %%
fb_A1likes_drop = fb_A1likes.dropna()
fb_A1likes_drop.size
# Out:
# 4909

# %%
fb_A1likes_z = (fb_A1likes_drop - fb_A1likes_drop.mean())/fb_A1likes_drop.std()

# %%
fb_A1likes_z
# Out:
# 0      -0.363705
# 1       2.217882
# 2       0.298240
# 3       1.357353
# 4      -0.421228
#           ...
# 4911   -0.387734
# 4912   -0.374230
# 4913   -0.429900
# 4914   -0.367280
# 4915   -0.424207
# Name: actor_1_facebook_likes, Length: 4909, dtype: float64

# %%
fb_A1likes_z.gt(3).sum() + fb_A1likes_z.lt(-3).sum()
# Out:
# 17

# %%
fb_A1likes_z.lt(-3).sum()
# Out:
# 0

# %%
fb_A1likes.fillna(0).astype(int).head()
# Out:
# 0     1000
# 1    40000
# 2    11000
# 3    27000
# 4      131
# Name: actor_1_facebook_likes, dtype: int32

# %%
(fb_A1likes.fillna(0)
     .astype(int)
     .head()
)
# Out:
# 0     1000
# 1    40000
# 2    11000
# 3    27000
# 4      131
# Name: actor_1_facebook_likes, dtype: int32

# %%
col_map = {
    "director_name": "director",
    "director_facebook_likes": "director_FB_likes",
}

# %%
df_movies.rename(columns=col_map).head(10)
# Out:
#    color           director  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_FB_likes  actor_3_facebook_likes       actor_2_name  \
# 0                0.0                   855.0   Joel David Moore
# 1              563.0                  1000.0      Orlando Bloom
# 2                0.0                   161.0       Rory Kinnear
# ...

# %%
total = (
    df_movies.actor_1_facebook_likes
    + df_movies.actor_2_facebook_likes
    + df_movies.actor_3_facebook_likes
    + df_movies.director_facebook_likes
)

# %%
total
# Out:
# 0        2791.0
# 1       46563.0
# 2       11554.0
# 3       95000.0
# 4           NaN
#          ...
# 4911     1427.0
# 4912        NaN
# 4913        0.0
# 4914     2154.0
# 4915      141.0
# Length: 4916, dtype: float64

# %%
total.head()
# Out:
# 0     2791.0
# 1    46563.0
# 2    11554.0
# 3    95000.0
# 4        NaN
# dtype: float64

# %%
df_movies.assign(total_likes=total).head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df_movies2 = df_movies.assign(total_likes=total)
df_movies2.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df_movies2 = df_movies2.drop(columns=["total_likes"])

# %%
df_movies2.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
fb_A1likes_drop + 10
# Out:
# 0        1010.0
# 1       40010.0
# 2       11010.0
# 3       27010.0
# 4         141.0
#          ...
# 4911      647.0
# 4912      851.0
# 4913       10.0
# 4914      956.0
# 4915       96.0
# Name: actor_1_facebook_likes, Length: 4909, dtype: float64

# %%
cols = [
    "actor_1_name",
    "actor_2_name",
    "actor_3_name",
    "director_name"
]
cols
# Out:
# ['actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name']

# %%
df_movie_names = df_movies[cols]

# %%
df_movie_names.head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name      director_name
# 0      CCH Pounder  Joel David Moore             Wes Studi      James Cameron
# 1      Johnny Depp     Orlando Bloom        Jack Davenport     Gore Verbinski
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4      Doug Walker        Rob Walker                   NaN        Doug Walker

# %%
df_movies.loc[:,cols]
# Out:
#          actor_1_name      actor_2_name          actor_3_name  \
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 4911      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 4912      Natalie Zea     Valorie Curry         Sam Underwood
# 4913      Eva Boehnke     Maxwell Moody        David Chandler
# 4914        Alan Ruck     Daniel Henney           Eliza Coupe
# 4915      John August  Brian Herzlinger              Jon Gunn
#
#           director_name
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# ...                 ...
# 4911        Scott Smith
# ...

# %%
df_movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df_movies.iloc[0,2]
# Out:
# 723.0

# %%
df_movies.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %%
df_movies.select_dtypes(include=["object"]).head()
# Out:
#    color      director_name      actor_2_name  \
# 0  Color      James Cameron  Joel David Moore
# 1  Color     Gore Verbinski     Orlando Bloom
# 2  Color         Sam Mendes      Rory Kinnear
# 3  Color  Christopher Nolan    Christian Bale
# 4    NaN        Doug Walker        Rob Walker
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                   movie_title          actor_3_name  \
# 0                                      Avatar             Wes Studi
# 1    Pirates of the Caribbean: At World's End        Jack Davenport
# 2                                     Spectre      Stephanie Sigman
# 3                       The Dark Knight Rises  Joseph Gordon-Levitt
# ...

# %%
df_movies.describe().T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4867.0  1.379889e+02  1.202394e+02     1.00
# duration                   4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes    4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes     4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes     4909.0  6.494488e+03  1.510699e+04     0.00
# gross                      4054.0  4.764451e+07  6.737255e+07   162.00
# num_voted_users            4916.0  8.264492e+04  1.383222e+05     5.00
# cast_total_facebook_likes  4916.0  9.579816e+03  1.816432e+04     0.00
# facenumber_in_poster       4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews       4895.0  2.676688e+02  3.729348e+02     1.00
# budget                     4432.0  3.654749e+07  1.002427e+08   218.00
# title_year                 4810.0  2.002448e+03  1.245398e+01  1916.00
# ...

# %%
# Check the version of pandas that you are using
pd.__version__
# Out:
# '1.0.5'

# %%
df_movies.describe().T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4867.0  1.379889e+02  1.202394e+02     1.00
# duration                   4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes    4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes     4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes     4909.0  6.494488e+03  1.510699e+04     0.00
# gross                      4054.0  4.764451e+07  6.737255e+07   162.00
# num_voted_users            4916.0  8.264492e+04  1.383222e+05     5.00
# cast_total_facebook_likes  4916.0  9.579816e+03  1.816432e+04     0.00
# facenumber_in_poster       4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews       4895.0  2.676688e+02  3.729348e+02     1.00
# budget                     4432.0  3.654749e+07  1.002427e+08   218.00
# title_year                 4810.0  2.002448e+03  1.245398e+01  1916.00
# ...

# %%
df_movies.country.fillna("").max()
# Out:
# 'West Germany'

# %%
df_college = pd.read_csv("Data\\college.csv",index_col="INSTNM")

# %%
df_college.columns
# Out:
# Index(['CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
df_diversity = df_college.filter(like="UGDS_")

# %%
df_diversity.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
df_diversity.isna().sum(axis="columns").eq(9).value_counts()
# Out:
# False    6874
# True      661
# dtype: int64

# %%
(
	df_diversity.isna()
	.sum(axis="columns")
	.sort_values(ascending=False)
	.head()
)
# Out:
# INSTNM
# Excel Learning Center-San Antonio South         9
# Philadelphia College of Osteopathic Medicine    9
# Assemblies of God Theological Seminary          9
# Episcopal Divinity School                       9
# Phillips Graduate Institute                     9
# dtype: int64

# %%
df_diversity = df_diversity.dropna(how="all")

# %%
df_diversity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6874 entries, Alabama A & M University to Coastal Pines Technical College
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UGDS_WHITE  6874 non-null   float64
#  1   UGDS_BLACK  6874 non-null   float64
#  2   UGDS_HISP   6874 non-null   float64
#  3   UGDS_ASIAN  6874 non-null   float64
#  4   UGDS_AIAN   6874 non-null   float64
#  5   UGDS_NHPI   6874 non-null   float64
#  6   UGDS_2MOR   6874 non-null   float64
#  7   UGDS_NRA    6874 non-null   float64
#  8   UGDS_UNKN   6874 non-null   float64
# dtypes: float64(9)
# memory usage: 537.0+ KB

# %%
metric = (
    df_diversity.ge(0.15)
    .sum(axis="columns")
)

# %%
metric.sort_values(ascending=False).head()
# Out:
# INSTNM
# Regency Beauty Institute-Austin          5
# Central Texas Beauty College-Temple      5
# Sullivan and Cogliano Training Center    4
# Ambria College of Nursing                4
# Berkeley College-New York                4
# dtype: int64

# %%
df_diversity.loc[["Regency Beauty Institute-Austin","Central Texas Beauty College-Temple"]]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Regency Beauty Institute-Austin          0.1867      0.2133     0.1600
# Central Texas Beauty College-Temple      0.1616      0.2323     0.2626
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Regency Beauty Institute-Austin          0.0000        0.0        0.0
# Central Texas Beauty College-Temple      0.0202        0.0        0.0
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# Regency Beauty Institute-Austin         0.1733       0.0     0.2667
# Central Texas Beauty College-Temple     0.1717       0.0     0.1515

# %%
df_diversity.loc[["Bucknell University"]]
# Out:
#                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  \
# INSTNM
# Bucknell University      0.7885      0.0317     0.0527      0.0357     0.0003
#
#                      UGDS_NHPI  UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# Bucknell University        0.0     0.0343     0.053     0.0037

# %%
df_college.describe(include="number").T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# ...

# %%
df_college.describe(include="object").T
# Out:
#                    count unique                top  freq
# CITY                7535   2514           New York    87
# STABBR              7535     59                 CA   773
# MD_EARN_WNE_P10     6413    598  PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038  PrivacySuppressed  1510

# %%
object_cols = df_college.select_dtypes('object').columns.tolist()

# %%
df_college[object_cols] = df_college[object_cols].astype('category')

# %%
df_college.dtypes
# Out:
# CITY                  category
# STABBR                category
# HBCU                   float64
# MENONLY                float64
# WOMENONLY              float64
# RELAFFIL                 int64
# SATVRMID               float64
# SATMTMID               float64
# DISTANCEONLY           float64
# UGDS                   float64
# UGDS_WHITE             float64
# UGDS_BLACK             float64
# UGDS_HISP              float64
# UGDS_ASIAN             float64
# UGDS_AIAN              float64
# UGDS_NHPI              float64
# UGDS_2MOR              float64
# UGDS_NRA               float64
# UGDS_UNKN              float64
# PPTUG_EF               float64
# CURROPER                 int64
# PCTPELL                float64
# PCTFLOAN               float64
# UG25ABV                float64
# MD_EARN_WNE_P10       category
# GRAD_DEBT_MDN_SUPP    category
# dtype: object

# %%
obj_cols =(
df_movies.select_dtypes(include=["object"])
.columns
.tolist()
)

# %%
obj_cols
# Out:
# ['color',
#  'director_name',
#  'actor_2_name',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'actor_3_name',
#  'plot_keywords',
#  'movie_imdb_link',
#  'language',
#  'country',
#  'content_rating']

# %%
df_movies[obj_cols] = df_movies[obj_cols].astype('category')

# %%
df_movies.color.cat.categories
# Out:
# Index(['Black and White', 'Color'], dtype='object')

# %%
df_movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
pd.get_dummies(df_movies.color)
# Out:
#       Black and White  Color
# 0                   0      1
# 1                   0      1
# 2                   0      1
# 3                   0      1
# 4                   0      0
# ...               ...    ...
# 4911                0      1
# 4912                0      1
# 4913                0      1
# 4914                0      1
# 4915                0      1
#
# [4916 rows x 2 columns]

# %%
df_movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df_movies.director_facebook_likes.max()
# Out:
# 23000.0

# %%
df_movies[
    (df_movies.color=='Color') & (df_movies.duration>=180)
    ].head()
# Out:
#     color  director_name  num_critic_for_reviews  duration  \
# 10  Color    Zack Snyder                   673.0     183.0
# 23  Color  Peter Jackson                   509.0     186.0
# 25  Color  Peter Jackson                   446.0     201.0
# 26  Color  James Cameron                   315.0     194.0
# 32  Color    Shane Black                   608.0     195.0
#
#     director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 10                      0.0                  2000.0        Lauren Cohan
# 23                      0.0                   773.0          Adam Brown
# 25                      0.0                    84.0  Thomas Kretschmann
# 26                      0.0                   794.0        Kate Winslet
# 32                   1000.0                  3000.0         Jon Favreau
#
#     actor_1_facebook_likes        gross                          genres  ...  \
# 10                 15000.0  330249062.0         Action|Adventure|Sci-Fi  ...
# ...

# %%
df_movies.loc[
    (df_movies.color=='Color') & (df_movies.duration>=180)
    ].head()
# Out:
#     color  director_name  num_critic_for_reviews  duration  \
# 10  Color    Zack Snyder                   673.0     183.0
# 23  Color  Peter Jackson                   509.0     186.0
# 25  Color  Peter Jackson                   446.0     201.0
# 26  Color  James Cameron                   315.0     194.0
# 32  Color    Shane Black                   608.0     195.0
#
#     director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 10                      0.0                  2000.0        Lauren Cohan
# 23                      0.0                   773.0          Adam Brown
# 25                      0.0                    84.0  Thomas Kretschmann
# 26                      0.0                   794.0        Kate Winslet
# 32                   1000.0                  3000.0         Jon Favreau
#
#     actor_1_facebook_likes        gross                          genres  ...  \
# 10                 15000.0  330249062.0         Action|Adventure|Sci-Fi  ...
# ...

# %%
df_movies.loc[df_movies['color'] == 'Color']
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df_titanic.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-767041331a53> in <module>
# ----> 1 df_titanic.columns
#
# NameError: name 'df_titanic' is not defined

# %%
df = pd.DataFrame({'a':[1, 2, 3], 'b':[1, 4, 3], 'c':[1, 4, 3]})
df
# Out:
#    a  b  c
# 0  1  1  1
# 1  2  4  4
# 2  3  3  3

# %%
from sklearn.preprocessing import Normalizer

# %%
trans = Normalizer(norm='l2')
pd.DataFrame(trans.fit_transform(df),columns=df.columns,index=df.index)
# Out:
#           a         b         c
# 0  0.577350  0.577350  0.577350
# 1  0.333333  0.666667  0.666667
# 2  0.577350  0.577350  0.577350

# %%
max = df.max(axis=1)
df.divide(max,axis=0)
# Out:
# 0    1
# 1    4
# 2    3
# dtype: int64

# %%
# Out:
#      a    b    c
# 0  1.0  1.0  1.0
# 1  0.5  1.0  1.0
# 2  1.0  1.0  1.0
